# %% [markdown]
# <a id="1"></a>
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:20px 80px;">📥 Importing libraries</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# <a id='2'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">📋 Data Collection</p>

# %%
#Extracting data
dataset=pd.read_csv('diabetes.csv')
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
#Our dataset dimesnions
dataset.shape
# Out:
# (2000, 9)

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:100px 100px;">📈 Statistical information of Dataset</p>

# %%
#Getting the Statistical Measures Of the Data
dataset.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
#Countng values of outcomes having 0 or 1, 0 means non diabetic and 1 means diabetic
sns.countplot(x='Outcome',data=dataset)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
dataset['Outcome'].value_counts()
# Out:
# 0    1316
# 1     684
# Name: Outcome, dtype: int64

# %%
dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness    Insulin  \
# Outcome
# 0           3.168693  110.586626      68.094985      20.052432  70.563830
# 1           4.732456  141.568713      71.166667      22.633041  98.897661
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.567477                  0.434676  31.081307
# 1        35.320468                  0.540681  36.956140

# %% [markdown]
#  <a id='3'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">📝 Correlation Matrix</p>

# %%
#Correlation matrix to show correlation between two variables, 0.x means x% similar
corr_mat=dataset.corr()
sns.heatmap(corr_mat, annot=True)
# Out:
# <AxesSubplot:>

# %%
#Ex: correlatiom between Glucose and Outcome is 47% that means output depends majorly on Glucose

# %% [markdown]
#  <a id='3'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">📝 Data Cleaning</p>

# %%
#Check if any null or empty data is present in dataset
dataset.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Feature matrix - Taking all our independent columns into single array and dependent values into another array
x=dataset.iloc[:,:-1].values  #Independent matrix
y=dataset.iloc[:,-1].values

# %%
x.shape
# Out:
# (2000, 8)

# %%
x[0] #refering to column 1 in dataset i.e pregnancies
# Out:
# array([2.00e+00, 1.38e+02, 6.20e+01, 3.50e+01, 0.00e+00, 3.36e+01,
#        1.27e-01, 4.70e+01])

# %%
y
# Out:
# array([1, 0, 1, ..., 0, 1, 0], dtype=int64)

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🎰 Exploratory Data Analysis & 📊 Data Visualization</p>

# %%
dataset.hist(figsize=(18,12))
plt.show()

# %%
#insulin for diabetic 

fig = plt.figure(figsize = (16,6))

sns.distplot(dataset["Insulin"][dataset["Outcome"]==1])
plt.xticks()
plt.title("Insulin",fontsize = 20)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Insulin')

# %%
#BMI for diabetic
fig = plt.figure(figsize =(16,6))

sns.distplot(dataset["BMI"][dataset["Outcome"]==1])
plt.xticks()
plt.title("BMI",fontsize = 20)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'BMI')

# %%
#diabeticpedigreefunction for diabetic
fig = plt.figure(figsize = (16,5))
sns.distplot(dataset["DiabetesPedigreeFunction"][dataset["Outcome"] == 1])
plt.xticks([i*0.15 for i in range(1,12)])
plt.title("diabetespedigreefunction")
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'diabetespedigreefunction')

# %%
#Age for diabetic
fig = plt.figure(figsize = (16,6))

sns.distplot(dataset["Age"][dataset["Outcome"] == 1])
plt.xticks([i*0.15 for i in range(1,12)])
plt.title("Age")
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Age')

# %%
plt.figure(figsize=(14,10))
sns.set_style(style='whitegrid')
plt.subplot(2,3,1)
sns.boxplot(x='Glucose',data=dataset)
plt.subplot(2,3,2)
sns.boxplot(x='BloodPressure',data=dataset)
plt.subplot(2,3,3)
sns.boxplot(x='Insulin',data=dataset)
plt.subplot(2,3,4)
sns.boxplot(x='BMI',data=dataset)
plt.subplot(2,3,5)
sns.boxplot(x='Age',data=dataset)
plt.subplot(2,3,6)
sns.boxplot(x='SkinThickness',data=dataset)
# Out:
# <AxesSubplot:xlabel='SkinThickness'>

# %%
 
mean_col = ['Glucose','BloodPressure','Insulin','Age','Outcome','BMI']

sns.pairplot(dataset[mean_col],palette='Accent')

# %%
sns.boxplot(x='Outcome',y='Insulin',data=dataset)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Insulin'>

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🐱‍🏍Train test split 🧐</p>

# %%
#Removing unnessary columns
x = dataset.drop(["Pregnancies","BloodPressure","SkinThickness","Outcome"],axis = 1)
y = dataset.iloc[:,-1]

# %%
#splitting dataset into training set and test set

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
#test_size 0.3 means for testing data 50% and training data 30%

# %%
x_train.shape #30% of original dataset (769,9) after removing unnecceasry data
# Out:
# (1400, 5)

# %%
x_test.shape #70% of original dataset (769,9) after removing unnecceasry data
# Out:
# (600, 5)

# %%
#Feature Scaling - To standardize the independent features present in the data in a fixed range.
#If feature scaling is not done, then a machine learning algorithm tends to weigh greater values, higher and consider smaller
#values as the lower values, regardless of the unit of the values. 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.59154072,  0.06688023,  0.26400148, -0.72697714, -0.76736899],
#        [ 0.52278005,  0.53660759,  0.45475768,  0.25176984,  1.48923396],
#        [-0.49868065, -0.7159987 , -0.52286786,  0.81631355,  2.53074301],
#        ...,
#        [-0.8082142 , -0.7159987 , -0.03405509, -0.96322641, -0.15982204],
#        [-1.11774775, -0.7159987 , -0.26057808, -0.53675045,  0.18734764],
#        [ 0.46087334, -0.7159987 , -3.84917915,  0.50642814,  3.13828996]])

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">📋 Model Apply</p>

# %% [markdown]
# # Model Building LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",model.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       397
#            1       0.72      0.56      0.63       203
#
#     accuracy                           0.78       600
#    macro avg       0.76      0.72      0.73       600
# weighted avg       0.77      0.78      0.77       600
#
# Confusion Matrix:
#  [[353  44]
#  [ 90 113]]
# Training Score:
#  76.42857142857142
# Mean Squared Error:
#  0.22333333333333333
# R2 score is:
#  0.002369991686416606

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 77.66666666666666

# %%
#So we get a accuracy score of 77.66 % using LogisticRegression Model

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top  Models</p>

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[353  44]
#  [ 90 113]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Support Vector Machine Model

# %%
from sklearn.svm import SVC
svc=SVC(kernel="linear",random_state=0)
svc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred=svc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",svc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       397
#            1       0.71      0.56      0.62       203
#
#     accuracy                           0.77       600
#    macro avg       0.75      0.72      0.73       600
# weighted avg       0.77      0.77      0.76       600
#
# Confusion Matrix:
#  [[350  47]
#  [ 90 113]]
# Training Score:
#  77.0
# Mean Squared Error:
#  0.22833333333333333
# R2 score is:
#  -0.019965008499708503

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 77.16666666666666

# %%
#So we get a accuracy score of 77.16 % using Support Vector Machine Model

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top Models</p>

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[350  47]
#  [ 90 113]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # KNeighborsClassifier Model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.87       397
#            1       0.76      0.68      0.72       203
#
#     accuracy                           0.82       600
#    macro avg       0.80      0.79      0.79       600
# weighted avg       0.82      0.82      0.82       600
#
# Confusion Matrix:
#  [[354  43]
#  [ 65 138]]
# Training Score:
#  84.57142857142857
# Mean Squared Error:
#  0.18
# R2 score is:
#  0.19593999329949996

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 82.0

# %%
#So we get a accuracy score of 82.0 % using KNeighborsClassifier

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top Models</p>

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[354  43]
#  [ 65 138]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb_classifier = GaussianNB()
nb_classifier.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
nb_y_pred =nb_classifier.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,nb_y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,nb_y_pred))
print("Training Score:\n",knn.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,nb_y_pred))
print("R2 score is:\n",r2_score(y_test,nb_y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       397
#            1       0.73      0.52      0.61       203
#
#     accuracy                           0.77       600
#    macro avg       0.76      0.71      0.72       600
# weighted avg       0.77      0.77      0.76       600
#
# Confusion Matrix:
#  [[357  40]
#  [ 97 106]]
# Training Score:
#  84.57142857142857
# Mean Squared Error:
#  0.22833333333333333
# R2 score is:
#  -0.019965008499708503

# %%
print(accuracy_score(y_test,nb_y_pred)*100)
# Out:
# 77.16666666666666

# %%
#So we get a accuracy score of 77.16 % using Naive Bayes

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top Models</p>

# %%
nb_cm = confusion_matrix(nb_y_pred,y_test)
print(nb_cm)
# Out:
# [[357  97]
#  [ 40 106]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(nb_cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",dtree.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       397
#            1       0.73      0.71      0.72       203
#
#     accuracy                           0.81       600
#    macro avg       0.79      0.79      0.79       600
# weighted avg       0.81      0.81      0.81       600
#
# Confusion Matrix:
#  [[344  53]
#  [ 59 144]]
# Training Score:
#  85.07142857142857
# Mean Squared Error:
#  0.18666666666666668
# R2 score is:
#  0.16615999305133322

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 81.33333333333333

# %%
#So we get a accuracy score of 81.33 % using DECISION TREE CLASSIFIER

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top Models</p>

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[344  53]
#  [ 59 144]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
print("Mean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("R2 score is:\n",r2_score(y_test,y_pred))
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       397
#            1       0.98      0.95      0.96       203
#
#     accuracy                           0.97       600
#    macro avg       0.98      0.97      0.97       600
# weighted avg       0.98      0.97      0.97       600
#
# Confusion Matrix:
#  [[393   4]
#  [ 11 192]]
# Training Score:
#  100.0
# Mean Squared Error:
#  0.025
# R2 score is:
#  0.888324999069375

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 97.5

# %%
#So we get a accuracy score of 97.5 % using RandomForestClassifier

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:120%;text-align:center;border-radius:100px 100px;">🌈Confusion Matrix of Top Models</p>

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[393   4]
#  [ 11 192]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Greens",annot=True,cbar_kws={"label":"color bar"},xticklabels=[0,1],yticklabels=[0,1],fmt="1.0f")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# <a id='4'></a>
# <div class="list-group" id="list-tab" role="tablist">
# <p style="background-color:#47b7ed;font-family:newtimeroman;color:#000000;font-size:150%;text-align:center;border-radius:100px 100px;">🧮 Models Score</p>

# %% [markdown]
# # So now we conclude the accuracy of different models:

# %%
#RandomForestClassifier=97.5%

# %%
#DECISION TREE CLASSIFIER=81.33%

# %%
#KNeighborsClassifier=77.16%

# %%
#LogisticRegression Model=77.66%

# %%
#Support Vector Machine=77.16%

# %%
#Naive Bayes=75.75%
